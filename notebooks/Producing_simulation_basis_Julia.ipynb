# %% [markdown]
# # Producing basis for Quack reconstruction

# %%
using HDF5
using LaTeXStrings
using Plots
using Format

using Random, Distributions
using EllipsisNotation

using LinearInterpolations

# %%
include("../src/QuackSim.jl")
using .QuackSim
# if installed:
#using QuackSim
# Out:
# WARNING: Imported binding CUDA.GPUArrays was undeclared at import time during import to Tullio.
# Reading sample information from /gpfs/exfel/data/scratch/danilo/gh/quacksim/src/../data/samples.h5
# [Tue, 15 Sep 2026 13:37:56] Readind information from orbital Ar2s
# [Tue, 15 Sep 2026 13:37:57] Readind information from orbital C1s
# [Tue, 15 Sep 2026 13:37:58] Readind information from orbital F1s
# [Tue, 15 Sep 2026 13:37:58] Readind information from orbital He1s
# [Tue, 15 Sep 2026 13:37:58] Readind information from orbital Kr1s
# [Tue, 15 Sep 2026 13:37:58] Readind information from orbital Kr4p_multi
# [Tue, 15 Sep 2026 13:37:58] Readind information from orbital N1s
# [Tue, 15 Sep 2026 13:37:58] Readind information from orbital Ne1s
# [Tue, 15 Sep 2026 13:37:58] Readind information from orbital O1s
# [Tue, 15 Sep 2026 13:37:58] Readind information from orbital S1s
# [Tue, 15 Sep 2026 13:37:58] Readind information from orbital Xe2p
# [Tue, 15 Sep 2026 13:37:58] Readind information from orbital Xe3d
# [Tue, 15 Sep 2026 13:37:58] Readind information from orbital Xe5p_multi
# [Tue, 15 Sep 2026 13:37:58] Readind information from orbital energy

# %%
# photo-electron kinetic energy axis (in eV) and angular axis (in rad)
minW = 95.0
maxW = 155.0
nbinsW = 160
W_axis = collect(LinRange(minW, maxW, nbinsW))
θ_axis = collect(range(0, 2π, step=2π/16.0))[1:16]
# Out:
# 16-element Vector{Float64}:
#  0.0
#  0.39269908169872414
#  0.7853981633974483
#  1.1780972450961724
#  1.5707963267948966
#  1.9634954084936207
#  2.356194490192345
#  2.748893571891069
#  3.141592653589793
#  3.5342917352885173
#  3.9269908169872414
#  4.319689898685965
#  4.71238898038469
#  5.105088062083414
#  5.497787143782138
#  5.890486225480862

# %%
# whether to use GPUs
use_gpu = false #true

# output H5 file
output = "testbasis.h5"

# ellipticity
epsilon = 1.0   

# gas
gas = "Ne1s"

# lser wavelength in nm
laser_wavelength = 1030


# maximum ponderomotive potentil, in eV
maxUp = 0.4

# linear FEL polarization
polarization=:horizontal    

# beta: Set to 0 for circular polarization, or 2 for linear polarization
beta = 2.0

# how much to oversample the FEL energy axis
oversampling = 1

# number of bins in time and in the ponderomotive potential axis
nbins_time = 128
nbins_Up = 64

# FEL central energy in eV
fel_energy = 1000.0
# Out:
# 1000.0

# %%
simulate_amplitude(
                   fel_energy=fel_energy,
                   W_axis=W_axis,
                   theta_axis=θ_axis,
                   laser_wavelength=laser_wavelength,
                   maxUp=maxUp,
                   output_filename=output,
                   gas=gas,
                   nbins_time=nbins_time,
                   nbins_Up=nbins_Up,
                   oversampling=oversampling,
                   use_gpu=use_gpu,
                   beta=beta,
                   polarization=polarization,
                   ellipticity=epsilon,
                   )
# Out:
# [Tue, 15 Sep 2026 13:38:01] Using analytical result for ϕ(t=Tl)...
# [Tue, 15 Sep 2026 13:38:04] Calculating b(t=Tl)...
# UndefVarError: `tda` not defined in `Main.QuackSim`
# Suggestion: check for spelling errors or missing imports.
# Stacktrace:
#   [1] dbamp!(du::Array{Float64, 5}, u::Array{Float64, 5}, p::SFAAmpSim, t::Float64, ϕT::Array{Float64, 3}, ω::Vector{Float64})
#     @ Main.QuackSim /gpfs/exfel/data/scratch/danilo/gh/quacksim/src/amplitude_simulation.jl:184
#   [2] (::Main.QuackSim.var"#60#61"{Vector{Float64}})(du::Array{Float64, 5}, u::Array{Float64, 5}, p::SFAAmpSim, t::Float64)
#     @ Main.QuackSim /gpfs/exfel/data/scratch/danilo/gh/quacksim/src/amplitude_simulation.jl:276
#   [3] Void
#     @ /gpfs/exfel/sw/software/julia-depot/202601/packages/SciMLBase/S0d2P/src/utils.jl:513 [inlined]
#   [4] (::FunctionWrappers.CallWrapper{…})(f::SciMLBase.Void{…}, arg1::Array{…}, arg2::Array{…}, arg3::SFAAmpSim, arg4::Float64)
#     @ FunctionWrappers /gpfs/exfel/sw/software/julia-depot/202601/packages/FunctionWrappers/Q5cBx/src/FunctionWrappers.jl:65
#   [5] macro expansion
#     @ /gpfs/exfel/sw/software/julia-depot/202601/packages/FunctionWrappers/Q5cBx/src/FunctionWrappers.jl:137 [inlined]
#   [6] do_ccall
#     @ /gpfs/exfel/sw/software/julia-depot/202601/packages/FunctionWrappers/Q5cBx/src/FunctionWrappers.jl:125 [inlined]
#   [7] FunctionWrapper
#     @ /gpfs/exfel/sw/software/julia-depot/202601/packages/FunctionWrappers/Q5cBx/src/FunctionWrappers.jl:144 [inlined]
#   [8] _call
#     @ /gpfs/exfel/sw/software/julia-depot/202601/packages/FunctionWrappersWrappers/7CPBX/src/FunctionWrappersWrappers.jl:392 [inlined]
#   [9] FunctionWrappersWrapper
#     @ /gpfs/exfel/sw/software/julia-depot/202601/packages/FunctionWrappersWrappers/7CPBX/src/FunctionWrappersWrappers.jl:384 [inlined]
#  [10] ODEFunction
#     @ /gpfs/exfel/sw/software/julia-depot/202601/packages/SciMLBase/S0d2P/src/scimlfunctions.jl:2662 [inlined]
#  [11] initialize!(integrator::OrdinaryDiffEqCore.ODEIntegrator{…}, cache::OrdinaryDiffEqTsit5.Tsit5Cache{…})
#     @ OrdinaryDiffEqTsit5 /gpfs/exfel/sw/software/julia-depot/202601/packages/OrdinaryDiffEqTsit5/8E8fO/src/tsit_perform_step.jl:197
#  [12] initialize!(integrator::OrdinaryDiffEqCore.ODEIntegrator{…}, cache::OrdinaryDiffEqCore.DefaultCache{…})
#     @ OrdinaryDiffEqCore /gpfs/exfel/sw/software/julia-depot/202601/packages/OrdinaryDiffEqCore/rnOL4/src/perform_step/composite_perform_step.jl:38
#  [13] _ode_init(prob::SciMLBase.ODEProblem{…}, alg::OrdinaryDiffEqCore.CompositeAlgorithm{…}, timeseries_init::Tuple{}, ts_init::Tuple{}, ks_init::Tuple{}; saveat::Float64, tstops::Tuple{}, d_discontinuities::Tuple{}, save_idxs::Nothing, save_everystep::Bool, save_on::Bool, save_discretes::Bool, save_start::Bool, save_end::Nothing, callback::SciMLBase.DiscreteCallback{…}, dense::Bool, calck::Bool, dt::Float64, dtmin::Float64, dtmax::Float64, force_dtmin::Bool, adaptive::Bool, abstol::Float64, reltol::Float64, gamma::Nothing, qmin::Nothing, qmax::Nothing, qsteady_min::Nothing, qsteady_max::Nothing, beta1::Nothing, beta2::Nothing, qoldinit::Nothing, fullnormalize::Bool, failfactor::Int64, maxiters::Int64, internalnorm::typeof(DiffEqBase.ODE_DEFAULT_NORM), internalopnorm::typeof(LinearAlgebra.opnorm), isoutofdomain::typeof(DiffEqBase.ODE_DEFAULT_ISOUTOFDOMAIN), unstable_check::typeof(DiffEqBase.ODE_DEFAULT_UNSTABLE_CHECK), verbose::Bool, controller::Nothing, timeseries_errors::Bool, dense_errors::Bool, advance_to_tstop::Bool, stop_at_next_tstop::Bool, initialize_save::Bool, progress::Bool, progress_steps::Int64, progress_name::String, progress_message::typeof(DiffEqBase.ODE_DEFAULT_PROG_MESSAGE), progress_id::Symbol, userdata::Nothing, allow_extrapolation::Bool, initialize_integrator::Bool, alias::SciMLBase.ODEAliasSpecifier, initializealg::DiffEqBase.DefaultInit, rng::Nothing, save_noise::Bool, delta::Nothing, W::Nothing, P::Nothing, sqdt::Nothing, noise::Nothing, c::Nothing, rate_constants::Nothing, _cache::Nothing, _u::Nothing, _uprev::Nothing, seed::UInt64, kwargs::@Kwargs{…})
#     @ OrdinaryDiffEqCore /gpfs/exfel/sw/software/julia-depot/202601/packages/OrdinaryDiffEqCore/rnOL4/src/solve.jl:813
#  [14] _ode_init
#     @ /gpfs/exfel/sw/software/julia-depot/202601/packages/OrdinaryDiffEqCore/rnOL4/src/solve.jl:47 [inlined]
#  [15] #__init#59
#     @ /gpfs/exfel/sw/software/julia-depot/202601/packages/OrdinaryDiffEqCore/rnOL4/src/solve.jl:37 [inlined]
#  [16] __init (repeats 2 times)
#     @ /gpfs/exfel/sw/software/julia-depot/202601/packages/OrdinaryDiffEqCore/rnOL4/src/solve.jl:19 [inlined]
#  [17] #__solve#58
#     @ /gpfs/exfel/sw/software/julia-depot/202601/packages/OrdinaryDiffEqCore/rnOL4/src/solve.jl:9 [inlined]
#  [18] __solve
#     @ /gpfs/exfel/sw/software/julia-depot/202601/packages/OrdinaryDiffEqCore/rnOL4/src/solve.jl:1 [inlined]
#  [19] #__solve#3
#     @ /gpfs/exfel/sw/software/julia-depot/202601/packages/OrdinaryDiffEqDefault/yrm4p/src/default_alg.jl:59 [inlined]
#  [20] __solve
#     @ /gpfs/exfel/sw/software/julia-depot/202601/packages/OrdinaryDiffEqDefault/yrm4p/src/default_alg.jl:58 [inlined]
#  [21] #solve_call#22
#     @ /gpfs/exfel/sw/software/julia-depot/202601/packages/DiffEqBase/CJTzr/src/solve.jl:172 [inlined]
#  [22] solve_call
#     @ /gpfs/exfel/sw/software/julia-depot/202601/packages/DiffEqBase/CJTzr/src/solve.jl:137 [inlined]
#  [23] #solve_up#29
#     @ /gpfs/exfel/sw/software/julia-depot/202601/packages/DiffEqBase/CJTzr/src/solve.jl:630 [inlined]
#  [24] solve_up
#     @ /gpfs/exfel/sw/software/julia-depot/202601/packages/DiffEqBase/CJTzr/src/solve.jl:619 [inlined]
#  [25] #solve#28
#     @ /gpfs/exfel/sw/software/julia-depot/202601/packages/DiffEqBase/CJTzr/src/solve.jl:603 [inlined]
#  [26] calculate_amplitude(p::SFAAmpSim, ω::Vector{Float64}; integration::Symbol)
#     @ Main.QuackSim /gpfs/exfel/data/scratch/danilo/gh/quacksim/src/amplitude_simulation.jl:286
#  [27] (::Main.QuackSim.var"#68#69"{Symbol})(k::UnitRange{Int64})
#     @ Main.QuackSim /gpfs/exfel/data/scratch/danilo/gh/quacksim/src/amplitude_simulation.jl:442
#  [28] (::Base.var"#938#939"{Main.QuackSim.var"#68#69"{Symbol}})(r::Base.RefValue{Any}, args::Tuple{UnitRange{Int64}})
#     @ Base ./asyncmap.jl:96
#  [29] (::Base.var"#start_worker_task!##0#start_worker_task!##1"{Base.var"#938#939"{…}, Channel{…}, Nothing})()
#     @ Base ./asyncmap.jl:230
#
# Stacktrace:
#   [1] (::Base.var"#maptwice##0#maptwice##1")(x::Task)
#     @ Base ./asyncmap.jl:173
#   [2] foreach(f::Base.var"#maptwice##0#maptwice##1", itr::Vector{Any})
#     @ Base ./abstractarray.jl:3188
#   [3] maptwice(wrapped_f::Function, chnl::Channel{Any}, worker_tasks::Vector{Any}, c::Vector{UnitRange{Int64}})
#     @ Base ./asyncmap.jl:173
#   [4] wrap_n_exec_twice
#     @ ./asyncmap.jl:149 [inlined]
#   [5] async_usemap(f::Main.QuackSim.var"#68#69"{Symbol}, c::Vector{UnitRange{Int64}}; ntasks::Int64, batch_size::Nothing)
#     @ Base ./asyncmap.jl:99
#   [6] async_usemap
#     @ ./asyncmap.jl:80 [inlined]
#   [7] #asyncmap#923
#     @ ./asyncmap.jl:77 [inlined]
#   [8] asyncmap
#     @ ./asyncmap.jl:76 [inlined]
#   [9] macro expansion
#     @ /gpfs/exfel/data/scratch/danilo/gh/quacksim/src/amplitude_simulation.jl:442 [inlined]
#  [10] macro expansion
#     @ ./task.jl:662 [inlined]
#  [11] simulate_amplitude(; fel_energy::Float64, W_axis::Vector{…}, theta_axis::Vector{…}, laser_wavelength::Int64, maxUp::Float64, output_filename::String, gas::String, ellipticity::Float64, nbins_time::Int64, nbins_Up::Int64, n_parallel::Int64, use_gpu::Bool, oversampling::Int64, integration::Symbol, beta::Float64, polarization::Symbol)
#     @ Main.QuackSim /gpfs/exfel/data/scratch/danilo/gh/quacksim/src/amplitude_simulation.jl:441
#  [12] top-level scope
#     @ In[5]:1
#  [13] eval(m::Module, e::Any)
#     @ Core ./boot.jl:489
# Some type information was truncated. Use `show(err)` to see complete types.
